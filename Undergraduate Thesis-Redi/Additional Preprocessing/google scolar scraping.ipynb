# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import re
import random

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
chrome_path = 'C:/Users/Redata/Downloads/read/chromedriver_win32/chromedriver.exe' # my directory for chrome driver
driver = webdriver.Chrome(chrome_path)

# %%
s = pd.DataFrame(columns=['text', "title", "publish", "link"])

for a in range(0,1000, 10): # we only got maximal 1000 result
    driver.get(f"https://scholar.google.com/scholar?start={a}&q=neet+young+people+neet+OR+young&hl=id&as_sdt=0,5")
    driver.execute_script(f"window.scrollTo(0, document.body.scrollHeight*{random.random()})")
    driver.implicitly_wait(2.2)
    html = driver.page_source
    satu = bs(html)
    i = satu.find_all("div", {"class":"gs_ri"})
    for x in i:
        text = x.get_text() #all text
        #cite = x.get_text().split("Cited by ")[1]
        title = x.find("h3","gs_rt").get_text()
        publish = x.find("div","gs_a").get_text()
        link = str(x.find("h3", {"class":"gs_rt"}))
        s = s.append({'text':text,"title":title, "publish":publish, "link":link}, ignore_index=True)
    driver.execute_script(f"window.scrollTo(0, document.body.scrollHeight*{random.random()})")
    driver.implicitly_wait(2.2)

# %%
s.to_csv("google_scholar_datascrape(dirty).csv")

# %% [markdown]
# # Little bit cleaning

# %%
s["cite"] = s["text"].str.split("Dirujuk ", expand=True)[1]
s["link"] = s["link"].str.split("href=", expand=True)[1].str.split("\"", expand=True)[1].str.replace("amp;", "")
d = s["publish"].str.split("-", expand=True).rename(columns={0:"author", 1:"journal/year", 2:"publisher"})
s[d.columns] = d
s["version"] = s["cite"].str.split("terkait ", expand=True)[1]
s["version"] = s["version"].str.extract(r'(\d+)').fillna(1)
s["citation"] = s["cite"].str.extract(r'(\d+)').fillna(0)
s.head()
# Out:
#                                                 text  \
# 0  Not so NEET? A critique of the use of 'NEET'in...
# 1  Social exclusion and the transition from schoo...
# 2  [BUKU][B] NEET young people and training for w...
# 3  [BUKU][B] NEETs: Young people not in employmen...
# 4  [HTML][HTML] A cross-sectional exploration of ...
#
#                                                title  \
# 0  Not so NEET? A critique of the use of 'NEET'in...
# 1  Social exclusion and the transition from schoo...
# 2  [BUKU][B] NEET young people and training for w...
# 3  [BUKU][B] NEETs: Young people not in employmen...
# 4  [HTML][HTML] A cross-sectional exploration of ...
#
#                                              publish  \
# 0  S Yates, M Payne - Journal of youth studies, 2...
# 1  J Bynner, S Parsons - Journal of vocational be...
# 2   R Simmons, R Thompson - 2011 - eprints.hud.ac.uk
# 3  M Mascherini, L Salvatore, A Meierkord, JM Jun...
# 4  B O'Dea, N Glozier, R Purcell, PD McGorry, J S...
#
#                                                 link  \
# 0  https://www.tandfonline.com/doi/abs/10.1080/13...
# 1  https://www.sciencedirect.com/science/article/...
# 2                     http://eprints.hud.ac.uk/11546
# 3         https://www.voced.edu.au/content/ngv:54087
# 4  https://bmjopen.bmj.com/content/4/12/e006378?u...
#
#                                        cite  \
# 0        287 kali Artikel terkait 4 versi
# 1        573 kali Artikel terkait 6 versi
# 2   79 kali Artikel terkait 4 versi  Cache
# 3  119 kali Artikel terkait 2 versi  Cache
# 4        55 kali Artikel terkait 16 versi
#
#                                               author  \
# 0                                  S Yates, M Payne
# 1                               J Bynner, S Parsons
# 2                             R Simmons, R Thompson
# 3  M Mascherini, L Salvatore, A Meierkord, JM Jun...
# 4  B O'Dea, N Glozier, R Purcell, PD McGorry, J S...
#
#                              journal/year           publisher     3     4  \
# 0         Journal of youth studies, 2006     Taylor & Francis  None  None
# 1   Journal of vocational behavior, 2002             Elsevier  None  None
# 2                                   2011    eprints.hud.ac.uk  None  None
# 3                                   2012         voced.edu.au  None  None
# 4                         BMJ open, 2014      bmjopen.bmj.com  None  None
#
#   version citation
# 0       4      287
# 1       6      573
# 2       4       79
# 3       2      119
# 4      16       55

# %%
o = s["journal/year"].str.extract(r'(\d+)')
p = s["publisher"].str.extract(r'(\d+)')
q = s[3].str.extract(r'(\d+)')
pd.concat([o, p, q], axis=1)
ui = pd.concat([o, p, q], axis=1).fillna(0)
for i in ui.columns:
    ui[i] = ui[i].astype("int")

zz = ui[((ui.iloc[:, 0] >= 1990) & (ui.iloc[:, 0] <= 2020)) | ((ui.iloc[:, 1] >= 1990) & (ui.iloc[:, 1] <= 2020))
        | ((ui.iloc[:, 2] >= 1990) & (ui.iloc[:, 2] <= 2020))]
s["year_publish"] = zz.sum(axis=1)

#still dirty
s["journal"] = s["journal/year"].str.split(",", expand=True)[[0, 1]].dropna()[0]

# %%
keyword = ["young", "youth", "NEET", "NEETs", "education", "training", "employment", "exclusion", 
           "16", "labour", "labor", "Not in"]

# %%
s.to_csv("google_scholar_datascrape.csv")

# %%
s.sort_values("year_publish").head(10)
# Out:
#                                                   text  \
# 399  Status zero youth and the underclassH Williams...
# 372  Not in education, employment, or training (NEE...
# 80   [BUKU][B] Young people not in education, emplo...
# 613  [PERNYATAAN][C] Young people not in education,...
# 453  [PERNYATAAN][C] A background to youth disaffec...
# 534  [BUKU][B] Keeping track mapping and tracking v...
# 857  Career guidance and social exclusion: a cautio...
# 912  Disconnected youth?R MacDonald, J Marsh - Jour...
# 1    Social exclusion and the transition from schoo...
# 75   [BUKU][B] Missing ConneXions: The Career Dynam...
#
#                                                  title  \
# 399               Status zero youth and the underclass
# 372  Not in education, employment, or training (NEE...
# 80   [BUKU][B] Young people not in education, emplo...
# 613  [PERNYATAAN][C] Young people not in education,...
# 453  [PERNYATAAN][C] A background to youth disaffec...
# 534  [BUKU][B] Keeping track mapping and tracking v...
# 857  Career guidance and social exclusion: a cautio...
# 912                                Disconnected youth?
# 1    Social exclusion and the transition from schoo...
# 75   [BUKU][B] Missing ConneXions: The Career Dynam...
#
#                                                publish  \
# 399  H Williamson - Youth, the 'underclass' and soc...
# 372  J Lee, K Woo - The Korean Labour Market after ...
# 80                       J Payne - 2000 - voced.edu.au
# 613  J Payne - LABOUR MARKET TRENDS, 2000 - … HOUSE...
# 453   R Steer - 2000 - … Development Foundation London
# 534  A Canny, AE Green, M Maguire - 2001 - micuat.e...
# 857  AG Watts - British Journal of Guidance & Couns...
# 912  R MacDonald, J Marsh - Journal of youth studie...
# 1    J Bynner, S Parsons - Journal of vocational be...
# 75   L Britton, B Chatrik, B Coles, G Craig, C Hylt...
#
#                                                   link  \
# 399  https://www.taylorfrancis.com/books/e/97802031...
# 372  https://www.taylorfrancis.com/books/e/97802031...
# 80          https://www.voced.edu.au/content/ngv:11552
# 613                                               None
# 453                                               None
# 534      https://micuat.enovation.ie/handle/10395/2179
# 857  https://www.tandfonline.com/doi/abs/10.1080/03...
# 912  https://www.tandfonline.com/doi/abs/10.1080/13...
# 1    https://www.sciencedirect.com/science/article/...
# 75                    https://eric.ed.gov/?id=ED474777
#
#                                               cite  \
# 399  180 kali Artikel terkait 5 versi  Versi HTML
# 372            2 kali Artikel terkait  Versi HTML
# 80                 16 kali Artikel terkait  Cache
# 613                      10 kali Artikel terkait
# 453                      42 kali Artikel terkait
# 534   31 kali Artikel terkait 8 versi  Versi HTML
# 857             132 kali Artikel terkait 4 versi
# 912             186 kali Artikel terkait 4 versi
# 1               573 kali Artikel terkait 6 versi
# 75                 38 kali Artikel terkait  Cache
#
#                                                 author  \
# 399                                      H Williamson
# 372                                      J Lee, K Woo
# 80                                            J Payne
# 613                                           J Payne
# 453                                           R Steer
# 534                      A Canny, AE Green, M Maguire
# 857                                          AG Watts
# 912                              R MacDonald, J Marsh
# 1                                 J Bynner, S Parsons
# 75   L Britton, B Chatrik, B Coles, G Craig, C Hylt...
#
#                                           journal/year  \
# 399   Youth, the 'underclass' and social exclusion ...
# 372   The Korean Labour Market after the 1997 …, 2013
# 80                                               2000
# 613                        LABOUR MARKET TRENDS, 2000
# 453                                              2000
# 534                                              2001
# 857   British Journal of Guidance & Counselling, 2001
# 912                    Journal of youth studies, 2001
# 1                Journal of vocational behavior, 2002
# 75                                               2002
#
#                             publisher     3     4 version citation  \
# 399                 taylorfrancis.com  None  None       5      180
# 372                 taylorfrancis.com  None  None       1        2
# 80                       voced.edu.au  None  None       1       16
# 613        … HOUSE COMMUNICATIONS PLC  None  None       1       10
# 453   … Development Foundation London  None  None       1       42
# 534               micuat.enovation.ie  None  None       8       31
# 857                  Taylor & Francis  None  None       4      132
# 912                  Taylor & Francis  None  None       4      186
# 1                            Elsevier  None  None       6      573
# 75                               ERIC  None  None       1       38
#
#                                         journal  year_publish
# 399                                       Youth        1997.0
# 372   The Korean Labour Market after the 1997 …        1997.0
# 80                                          NaN        2000.0
# 613                        LABOUR MARKET TRENDS        2000.0
# 453                                         NaN        2000.0
# 534                                         NaN        2001.0
# 857   British Journal of Guidance & Counselling        2001.0
# 912                    Journal of youth studies        2001.0
# 1                Journal of vocational behavior        2002.0
# 75                                          NaN        2002.0
